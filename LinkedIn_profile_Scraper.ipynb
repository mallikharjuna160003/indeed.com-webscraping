# %%
import requests,time
from bs4 import BeautifulSoup
from selenium import webdriver
import csv

# %%
browser = webdriver.Firefox()
browser.get('https://www.linkedin.com/login?fromSignIn=true&trk=guest_homepage-basic_nav-header-signin')
#reading credential from file

with open("login.csv") as f1:
    csvrow = csv.reader(f1 , delimiter = ",")
    for row in csvrow:
        username = row[0]
        password = row[1]
elementID = browser.find_element_by_id('username')
elementID.send_keys(username)
elementID = browser.find_element_by_id('password')
elementID.send_keys(password)
elementID.submit()

# %%
link = 'https://www.linkedin.com/in/rishabh-singh-61b706114/'
browser.get(link)

# %%
SCROLL_PAUSE_TIME = 5

#Get scroll height
last_height = browser.execute_script("return document.body.scrollHeight")

for i in range(3):
    #scroll down to bottom
    browser.execute_script("window.scrollTo(0,document.body.scrollHeight);")
    
    #wait to load page
    time.sleep(SCROLL_PAUSE_TIME)
    
    #Calculate new scroll height and compare with last scroll height
    new_height = browser.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height =new_height

# %%
src = browser.page_source
soup = BeautifulSoup(src,'lxml')
soup
# Out:
# <html class="theme theme--mercado artdeco" lang="en"><head>
# <script async="" src="https://platform.linkedin.com/js/analytics.js"></script><script type="application/javascript">!function(i,n){void 0!==i.addEventListener&&void 0!==i.hidden&&(n.liVisibilityChangeListener=function(){i.hidden&&(n.liHasWindowHidden=!0)},i.addEventListener("visibilitychange",n.liVisibilityChangeListener))}(document,window);</script>
# <title>Rishabh Singh | LinkedIn</title>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta class="mercado-icons-sprite" content="https://static-exp1.licdn.com/sc/h/21m48fftxrxil7c8lck4bcp41" id="artdeco-icons/static/images/sprite-asset" name="asset-url"/>
# <meta content="" name="description"/>
# <meta content="notranslate" name="google"/>
# <meta content="false" name="is-http2"/>
# <meta content="voyager-web" name="service"/>
# <meta content="#0077B5" name="theme-color"/>
# <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0" name="viewport"/>
# <link href="/voyager/manifest.json" rel="manifest"/>
# <link href="https://static-exp1.licdn.com/sc/h/dv1zh646h7rdgxjmyomxqgjpx" id="ui-theme" rel="stylesheet"/>
# <link disabled="" href="https://static-exp1.licdn.com/sc/h/1t4f3j6215rnv12edmlqen20f" id="ui-theme-dark" rel="stylesheet"/>
# <link href="https://static-exp1.licdn.com/sc/h/87ehmn01991spr4frpkmsgafu" rel="stylesheet"/>
# <meta content="%7B%22modulePrefix%22%3A%22extended%22%2C%22environment%22%3A%22production%22%2C%22ember-a11y-testing%22%3A%7B%22componentOptions%22%3A%7B%22turnAuditOff%22%3Atrue%2C%22excludeAxeCore%22%3Atrue%2C%22axeOptions%22%3A%7B%22iframes%22%3Afalse%2C%22reporter%22%3A%22v2%22%2C%22resultTypes%22%3A%5B%22violations%22%5D%2C%22rules%22%3A%7B%22duplicate-id%22%3A%7B%22enabled%22%3Afalse%7D%2C%22duplicate-id-active%22%3A%7B%22enabled%22%3Afalse%7D%2C%22duplicate-id-aria%22%3A%7B%22enabled%22%3Afalse%7D%7D%7D%7D%7D%2C%22client-sensor-web%22%3A%7B%22mpName%22%3A%22voyager-web%22%7D%2C%22ember-media-player%22%3A%7B%22lazyLoad%22%3Atrue%7D%2C%22ember-fetch%22%3A%7B%22preferNative%22%3Atrue%7D%2C%22rootURL%22%3A%22%2F%22%2C%22routerRootURL%22%3A%22%2F%22%2C%22deviceFormFactor%22%3A%22DESKTOP%22%2C%22locationType%22%3A%22voyager-location%22%2C%22namespace%22%3A%22voyager%2Fapi%22%2C%22EmberENV%22%3A%7B%22FEATURES%22%3A%7B%7D%2C%22_APPLICATION_TEMPLATE_WRAPPER%22%3Afalse%2C%22_DEFAULT_ASYNC_OBSERVERS%22%3Atrue%2C%22_JQUERY_INTEGRATION%22%3Afalse%2C%22_TEMPLATE_ONLY_GLIMMER_COMPONENTS%22%3Atrue%7D%2C%22APP%22%3A%7B%22locale%22%3A%22en_US%22%2C%22rumConfig%22%3A%7B%22pageKeyPrefix%22%3A%22d_%22%2C%22beacon-service%22%3A%22tracking%22%2C%22beacon-url%22%3A%22%2Fli%2Ftrack%22%2C%22event-name%22%3A%22RealUserMonitoringEvent%22%2C%22enable-cdn-tracking%22%3Atrue%2C%22enable-pop-tracking%22%3Atrue%2C%22user-timing-mark-enabled%22%3Atrue%7D%2C%22name%22%3A%22extended%22%2C%22version%22%3A%22voyager-web_1.7.6591%2B2987922c%22%7D%2C%22contentSecurityPolicy%22%3A%7B%22default-src%22%3A%22%5C%22none%5C%22%20*.licdn.com%20*.licdn-ei.com%22%2C%22script-src%22%3A%22%5C%22self%5C%22%20%5C%22unsafe-inline%5C%22%20*.licdn.com%20*.licdn-ei.com%20*.linkedin.com%22%2C%22font-src%22%3A%22%5C%22self%5C%22%20*.licdn.com%20*.licdn-ei.com%20*.slidesharecdn.com%22%2C%22frame-src%22%3A%22*.youtube.com%20*.slideshare.net%22%2C%22connect-src%22%3A%22%5C%22self%5C%22%20localhost%3A*%20*.linkedin.com%22%2C%22img-src%22%3A%22%5C%22self%5C%22%20*.slidesharecdn.com%20*.licdn.com%20*.licdn-ei.com%20spdy.linkedin.com%20spdy.linkedin-ei.com%20*.youtube.com%22%2C%22style-src%22%3A%22%5C%22self%5C%22%20%5C%22unsafe-inline%5C%22%20*.licdn.com%20*.licdn-ei.com%22%2C%22media-src%22%3A%22%5C%22self%5C%22%20*.slidesharecdn.com%20*.licdn.com%20*.licdn-ei.com%22%7D%2C%22tracking%22%3A%7B%22validation%22%3A%7B%22throwOnError%22%3Atrue%7D%2C%22appId%22%3A%22com.linkedin.flagship3.d_web%22%2C%22pageKeyPrefix%22%3A%22d_%22%2C%22pveTrackingInfo%22%3A%7B%22osName%22%3A%22phone_web%22%7D%2C%22impression%22%3A%7B%22timeThreshold%22%3A300%2C%22percentageThreshold%22%3A50%2C%22viewportOffset%22%3A%7B%22top%22%3A52%2C%22bottom%22%3A0%2C%22left%22%3A0%2C%22right%22%3A0%7D%7D%2C%22comScore%22%3A%7B%22enabled%22%3Atrue%7D%7D%2C%22enableComponentUsageReport%22%3Afalse%2C%22i18n%22%3A%7B%22cldrModeLixKey%22%3A%22voyager.web.global-i18n-cldr-mode%22%7D%2C%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets%2Fimg%2Forganization%2Ffacepile%2FMan_08.png%22%2C%22assets%2Fimg%2Forganization%2Ffacepile%2FMan_11.png%22%2C%22assets%2Fimg%2Forganization%2Ffacepile%2FWoman_17.png%22%2C%22assets%2Fimg%2Fchina-icp-filing.png%22%2C%22assets%2Fimg%2Forganization%2Fdesktop-screenshot.png%22%2C%22assets%2Fimg%2Forganization%2Fmobile-screenshot.png%22%2C%22assets%2Fimg%2Fprofile%2Fdesktop-photo-upload-add-photo.png%22%2C%22assets%2Fhighcharts%2Fhighcharts.js%22%2C%22assets%2Fhighcharts%2Fmodules%2Fmap.js%22%2C%22assets%2Fhighcharts%2Fmodules%2Faccessibility.js%22%2C%22assets%2FcloudSDK%2FOneDriveSDK.js%22%2C%22assets%2FcloudSDK%2FDropboxSDK.js%22%2C%22assets%2Fproj4.js%22%2C%22assets%2Fspectroscopy-worker.js%22%2C%22assets%2Fworld.js%22%2C%22assets%2Fsrc%2Fchartbeat.js%22%2C%22assets%2Fpowerpoint-coach%2FCoachPackage.js%22%2C%22assets%2Ffavicon.ico%22%2C%22assets%2Ffavicon-notification.ico%22%2C%22assets%2Fimg%2Fhiring%2Fcm-upsell%2Fdesktop-cm-upsell-facepile%402x.png%22%2C%22assets%2Fimg%2Fhiring%2F ...
# <!-- EMBER_CLI_FASTBOOT_TITLE --><!-- EMBER_CLI_FASTBOOT_HEAD -->
# <link href="https://static-exp1.licdn.com/sc/h/al2o9zrvru7aqj8e1x2rzsrca" id="favicon-ico" rel="shortcut icon"/>
# <link href="https://static-exp1.licdn.com/sc/h/2if24wp7oqlodqdlgei1n1520" rel="apple-touch-icon"/>
# <link href="https://static-exp1.licdn.com/sc/h/eahiplrwoq61f4uan012ia17i" rel="apple-touch-icon-precomposed"/>
# <link href="https://static-exp1.licdn.com/sc/h/2if24wp7oqlodqdlgei1n1520" rel="apple-touch-icon-precomposed" sizes="57x57"/>
# <link href="https://static-exp1.licdn.com/sc/h/eahiplrwoq61f4uan012ia17i" rel="apple-touch-icon-precomposed" sizes="144x144"/>
# <link href="https://static-exp1.licdn.com/sc/h/3unnxtiw479mxh3vzui64xeq8" rel="stylesheet"/>
# <link href="https://static-exp1.licdn.com/sc/h/dg6xasivn36d999nx5js547xw" rel="stylesheet"/>
# <meta content='{"assets/img/organization/facepile/Man_08.png":"https://static-exp1.licdn.com/sc/h/3o5hiooua9mbbubbzedvypuug","assets/img/organization/facepile/Man_11.png":"https://static-exp1.licdn.com/sc/h/8gm9tyw8v6dpf8h885mp8v3oz","assets/img/organization/facepile/Woman_17.png":"https://static-exp1.licdn.com/sc/h/cxwbr3jqacyw9dme6x58vm9j4","assets/img/china-icp-filing.png":"https://static-exp1.licdn.com/sc/h/cbn91jpp9vuid7olk3y6qmbpj","assets/img/organization/desktop-screenshot.png":"https://static-exp1.licdn.com/sc/h/ev2ewp91pnvtl0gcyt4xht0b5","assets/img/organization/mobile-screenshot.png":"https://static-exp1.licdn.com/sc/h/3v3wzhnr3kapuzwpk1zt6r1jt","assets/img/profile/desktop-photo-upload-add-photo.png":"https://static-exp1.licdn.com/sc/h/c5ybm82ti04zuasz2a0ubx7bu","assets/highcharts/highcharts.js":"https://static-exp1.licdn.com/sc/h/c3q5zlpsg59fbn54rwjbn6qpz","assets/highcharts/modules/map.js":"https://static-exp1.licdn.com/sc/h/8o2eduyp6y1pu9r7grqvjvk4w","assets/highcharts/modules/accessibility.js":"https://static-exp1.licdn.com/sc/h/dsixagj33j19bv2yaqx4o2w19","assets/cloudSDK/OneDriveSDK.js":"https://static-exp1.licdn.com/sc/h/94jnj61sm1bg83wxkh3pi6cbm","assets/cloudSDK/DropboxSDK.js":"https://static-exp1.licdn.com/sc/h/dsnobpt79m5wl02pka5e9jqf5","assets/proj4.js":"https://static-exp1.licdn.com/sc/h/9bl0wb0mwh76g4x7n71c44j5g","assets/spectroscopy-worker.js":"https://static-exp1.licdn.com/sc/h/69miyr75u4gp5utz4wgun9dya","assets/world.js":"https://static-exp1.licdn.com/sc/h/r2hsqldtnfiip06hrrucb2iv","assets/src/chartbeat.js":"https://static-exp1.licdn.com/sc/h/38cn54yhuf7hiuild4i14mfcx","assets/powerpoint-coach/CoachPackage.js":"https://static-exp1.licdn.com/sc/h/17nctgja05dz4mhku63huks4d","assets/favicon.ico":"https://static-exp1.licdn.com/sc/h/al2o9zrvru7aqj8e1x2rzsrca","assets/favicon-notification.ico":"https://static-exp1.licdn.com/sc/h/1bt1uwq5akv756knzdj4l6cdc","assets/img/hiring/cm-upsell/desktop-cm-upsell-facepile@2x.png":"https://static-exp1.licdn.com/sc/h/8ystu86iged5on2a0z86f2ko3","assets/img/hiring/onboarding/new-poster-desktop-modal-image@2x.png":"https://static-exp1.licdn.com/sc/h/ewdoimk3v63x2o3nsi6rharus","assets/img/premium/products/slides/job_seeker_featured_applicant_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/6gl4ufmcgffyhuu4lti3us9mr","assets/img/premium/products/slides/job_seeker_inmail_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/194ufzr1ibusivbechyc149ox","assets/img/premium/products/slides/job_seeker_job_insights_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/b9qvh5p1l68rq61pvb6f3dpin","assets/img/premium/products/slides/job_seeker_professional_learning_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/75zb38b8070xlgfvx5ta8ksg5","assets/img/premium/products/slides/job_seeker_professional_wvmp_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/85swj4u5h27rp1gv0gtu5568","assets/img/premium/products/slides/job_seeker_resume_builder_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/b7ybzpxcq6ma06b6jrssqcu5v","assets/img/premium/products/slides/job_seeker_interview_prep_648x468_v1.png":"https://static-exp1.licdn.com/sc/h/dxj16dv0q0dlpveh17ftnocke","assets/img/premium/products/slides/learning_certificates_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/583fidw259ymymoncldari2wo","assets/img/premium/products/slides/learning_experts_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/c6188n1g55fuxv51sx0ldfc9a","assets/img/premium/products/slides/learning_practice_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/cu8z4dheitoo3j58t2hzsnriu","assets/img/premium/products/slides/learning_recommendations_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/czbqzystj2cf6vcdikti5qpxl","assets/img/premium/products/slides/learning_time_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/f13ctg6tjp7cnaf9orkc9m1lz","assets/img/premium/products/slides/learning_topics_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/eazvcix8vc8qb5vead285sqcq","assets/img/premium/products/slides/lear ...
# <meta content="en_US" name="i18nDefaultLocale"/>
# <meta content="en_US" name="i18nLocale"/>
# <meta content="https://static-exp1.licdn.com/sc/h/8uushqzld2h40b2tbglxqobfm" name="i18nIntlPolyfillUrl"/>
# <meta content="in" name="requestIpCountryCode"/>
# <meta content="urn:li:page:bpr;kqi4qNZYQL+lizFr+zVgPA==" name="bprPageInstance"/>
# <meta content='{"applicationUrn": "urn:li:application:(voyager-web,voyager-web)", "version": "1.7.6591", "trackingId": [-116, -59, -62, 59, -50, 54, 65, -70, -112, -60, 43, -95, -54, -15, -80, 13]}' name="applicationInstance"/>
# <meta content="TSTHXtgdSY+wPdUAVOMC1w==" name="clientPageInstanceId"/>
# <meta content="voyager-web" name="service"/>
# <meta content="i001" name="serviceInstance"/>
# <meta content="1.7.6591" name="serviceVersion"/>
# <meta content="XaYde5UGTxYQR4MIFysAAA==" name="treeID"/>
# <meta content="none" name="liamOrLisa"/>
# <meta content='{"routingLix":{"engines":{"profile-tetris":{"lixKey":"voyager.web.profile-pre-tetris","lixedEngine":"profile"}}},"lix":{"voyager.web.nav.job-posting-jobs-led-entry-points":{"treatment":"control","trackingInfo":null,"testKey":"voyager.web.nav.job-posting-jobs-led-entry-points","primaryEvaluationUrn":null},"voyager.web.global-i18n-cldr-mode":{"treatment":"enabled","trackingInfo":null,"testKey":"voyager.web.global-i18n-cldr-mode","primaryEvaluationUrn":null},"voyager.web.jobs-home-post-free-job":{"treatment":"enabled","trackingInfo":{"segmentIndex":9,"treatmentIndex":1,"experimentId":3684915,"urn":"urn:li:member:863434153","trackingUrns":null},"testKey":"voyager.web.jobs-home-post-free-job","primaryEvaluationUrn":null},"voyager.iac.web.import-communities":{"treatment":"control","trackingInfo":null,"testKey":"voyager.iac.web.import-communities","primaryEvaluationUrn":null},"voyager.web.get-career-guidance-onboarding-modal":{"treatment":"treatment","trackingInfo":null,"testKey":"voyager.web.get-career-guidance-onboarding-modal","primaryEvaluationUrn":null},"voyager.web.infraux-mercado-theme":{"treatment":"enabled","trackingInfo":{"segmentIndex":6,"treatmentIndex":1,"experimentId":3691642,"urn":"urn:li:member:863434153","trackingUrns":null},"testKey":"voyager.web.infraux-mercado-theme","primaryEvaluationUrn":null},"voyager.web.smp-generic-rfp":{"treatment":"control","trackingInfo":null,"testKey":"voyager.web.smp-generic-rfp","primaryEvaluationUrn":null},"voyager.web.groups-optin-notification-lego-call-enabled":{"treatment":"control","trackingInfo":{"segmentIndex":1,"treatmentIndex":0,"experimentId":3665952,"urn":"urn:li:member:863434153","trackingUrns":null},"testKey":"voyager.web.groups-optin-notification-lego-call-enabled","primaryEvaluationUrn":null},"voyager.web.participate-social-detail-rollback":{"treatment":"control","trackingInfo":{"segmentIndex":1,"treatmentIndex":0,"experimentId":3707194,"urn":"urn:li:member:863434153","trackingUrns":null},"testKey":"voyager.web.participate-social-detail-rollback","primaryEvaluationUrn":null},"voyager.web.hiring-manager-satisfaction-question-v2":{"treatment":"enabled","trackingInfo":null,"testKey":"voyager.web.hiring-manager-satisfaction-question-v2","primaryEvaluationUrn":null},"voyager.web.video-image-vector-error-message":{"treatment":"control","trackingInfo":{"segmentIndex":1,"treatmentIndex":0,"experimentId":3708233,"urn":"urn:li:member:863434153","trackingUrns":null},"testKey":"voyager.web.video-image-vector-error-message","primaryEvaluationUrn":null},"voyager.web.messaging-conversation-bubble-one-click-actions":{"treatment":"control","trackingInfo":{"segmentIndex":1,"treatmentIndex":0,"experimentId":3693641,"urn":"urn:li:member:863434153","trackingUrns":null},"testKey":"voyager.web.messaging-conversation-bubble-one-click-actions","primaryEvaluationUrn":null},"voyager.web.participate-commentV2-text-view-model":{"treatment":"control","trackingInfo":null,"testKey":"voyager.web.participate-commentV2-text-view-model","primaryEvaluationUrn":null},"voyager.web.messaging-one-or-two-person-chat-small-bubble":{"treatment":"control","trackingInfo":{"segmentIndex":1,"treatmentIndex":0,"experimentId":3707492,"urn":"urn:li:member:863434153","trackingUrns":null},"testKey":"voyager.web.messaging-one-or-two-person-chat-small-bubble","primaryEvaluationUrn":null},"voyager.web.live-video-quiet-mode":{"treatment":"enabled","trackingInfo":null,"testKey":"voyager.web.live-video-quiet-mode","primaryEvaluationUrn":null},"voyager.web.premium.sales-nav-for-professionals-nav-identity-upsell":{"treatment":"control","trackingInfo":null,"testKey":"voyager.web.premium.sales-nav-for-professionals-nav-identity-upsell","primaryEvaluationUrn":null},"voyager.web.careers-promoted-badge-on-job-card":{"treatment":"control","trackingInfo":{"segmentIndex":1,"treatmentIndex":0,"experimentId":3712523,"urn":"urn:li:member:863434153","trackingUrns":null},"testKey":"voyager.web.careers-promoted-badge-on-job-card", ...
# <meta content="false" name="isGuest"/>
# <meta data-mode="BIGPIPE" name="renderingMode"/>
# <!--%SSR_HEAD*[]%-->
# <meta content="enabled" name="Fastlane"/>
# <meta content="12000" name="bigpipeResponseTimeout"/>
# <meta content="false" name="bigpipeJetRethrowError"/>
# <meta content='["static\\.licdn\\.com","media\\.licdn\\.com","voyager/api/typeahead/hits"]' name="bigpipeBlacklistUrls"/>
# <meta content="true" name="isQueryTunnelRequestSupported"/>
# <script src="https://static-exp1.licdn.com/sc/h/40nkwms0jpasv7yh3fxgj2zju"></script>
# <meta content="%7B%7D" name="abi/config/environment"/>
# <meta content="%7B%7D" name="article-reader/config/environment"/>
# <meta content="%7B%7D" name="career-services/config/environment"/>
# <meta content="%7B%7D" name="colleagues/config/environment"/>
# <meta content="%7B%7D" name="company-creation/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="discover-tab/config/environment"/>
# <meta content="%7B%7D" name="emoji-picker/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="events/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="events-analytics/config/environment"/>
# <meta content="%7B%7D" name="events-networking-tables/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="feed/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="feed-detail/config/environment"/>
# <meta content="%7B%7D" name="feed-shared/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="groups/config/environment"/>
# <meta content="%7B%7D" name="hiring/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="inshare/config/environment"/>
# <meta content="%7B%7D" name="interview-prep/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="jobs/config/environment"/>
# <meta content="%7B%7D" name="jobs-post-apply/config/environment"/>
# <meta content="%7B%22googleAnalytics%22%3A%7B%22trackingId%22%3A%22UA-62256447-1%22%7D%2C%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="jobs-search/config/environment"/>
# <meta content="%7B%7D" name="lead-capture/config/environment"/>
# <meta content="%7B%7D" name="lead-gen/config/environment"/>
# <meta content="%7B%7D" name="me/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="me-ca/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="messaging/config/environment"/>
# <meta content="%7B%7D" name="msg-conversation-ui/config/environment"/>
# <meta content="%7B%7D" name="msg-hiring/config/environment"/>
# <meta content="%7B%7D" name="msg-mentions/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="msg-overlay/config/environment"/>
# <meta content="%7B%7D" name="msg-referrals/config/environment"/>
# <meta content="%7B%7D" name="msg-rich-media/config/environment"/>
# <meta content="%7B%7D" name="msg-shared-modals/config/environment"/>
# <meta content="%7B%7D" name="msg-spinmail/config/environment"/>
# <meta content="%7B%7D" name="msg-ui/config/environment"/>
# <meta content="%7B%7D" name="mynetwork/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="news/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="notifications/config/environment"/>
# <meta content="%7B%7D" name="onboarding/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="organization/config/environment"/>
# <meta content="%7B%7D" name="organization-about/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="organization-admin/config/environment"/>
# <meta content="%7B%7D" name="organization-alumni-talent/config/environment"/>
# <meta content="%7B%7D" name="organization-content-suggestions/config/environment"/>
# <meta content="%7B%7D" name="organization-employee-experience/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="organization-events/config/environment"/>
# <meta content="%7B%7D" name="organization-insights/config/environment"/>
# <meta content="%7B%7D" name="organization-jobs/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="organization-life/config/environment"/>
# <meta content="%7B%7D" name="organization-people/config/environment"/>
# <meta content="%7B%7D" name="organization-posts/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="organization-videos/config/environment"/>
# <meta content="%7B%7D" name="participate-text-editor/config/environment"/>
# <meta content="%7B%7D" name="premium/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="products/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%2C%22environment%22%3A%22production%22%2C%22ember-a11y-testing%22%3A%7B%22componentOptions%22%3A%7B%22turnAuditOff%22%3Atrue%2C%22excludeAxeCore%22%3Atrue%2C%22axeOptions%22%3A%7B%22iframes%22%3Afalse%2C%22reporter%22%3A%22v2%22%2C%22resultTypes%22%3A%5B%22violations%22%5D%2C%22rules%22%3A%7B%22duplicate-id%22%3A%7B%22enabled%22%3Afalse%7D%2C%22duplicate-id-active%22%3A%7B%22enabled%22%3Afalse%7D%2C%22duplicate-id-aria%22%3A%7B%22enabled%22%3Afalse%7D%7D%7D%7D%7D%7D" name="profile/config/environment"/>
# <meta content="%7B%22environment%22%3A%22production%22%2C%22ember-a11y-testing%22%3A%7B%22componentOptions%22%3A%7B%22turnAuditOff%22%3Atrue%2C%22excludeAxeCore%22%3Atrue%2C%22axeOptions%22%3A%7B%22iframes%22%3Afalse%2C%22reporter%22%3A%22v2%22%2C%22resultTypes%22%3A%5B%22violations%22%5D%2C%22rules%22%3A%7B%22duplicate-id%22%3A%7B%22enabled%22%3Afalse%7D%2C%22duplicate-id-active%22%3A%7B%22enabled%22%3Afalse%7D%2C%22duplicate-id-aria%22%3A%7B%22enabled%22%3Afalse%7D%7D%7D%7D%7D%7D" name="profile-edit/config/environment"/>
# <meta content="%7B%7D" name="profile-ge/config/environment"/>
# <meta content="%7B%7D" name="profile-opportunities/config/environment"/>
# <meta content="%7B%7D" name="profile-search-analytics/config/environment"/>
# <meta content="%7B%7D" name="profile-skill-assessments/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%2C%22environment%22%3A%22production%22%2C%22ember-a11y-testing%22%3A%7B%22componentOptions%22%3A%7B%22turnAuditOff%22%3Atrue%2C%22excludeAxeCore%22%3Atrue%2C%22axeOptions%22%3A%7B%22iframes%22%3Afalse%2C%22reporter%22%3A%22v2%22%2C%22resultTypes%22%3A%5B%22violations%22%5D%2C%22rules%22%3A%7B%22duplicate-id%22%3A%7B%22enabled%22%3Afalse%7D%2C%22duplicate-id-active%22%3A%7B%22enabled%22%3Afalse%7D%2C%22duplicate-id-aria%22%3A%7B%22enabled%22%3Afalse%7D%7D%7D%7D%7D%7D" name="profile-subroutes/config/environment"/>
# <meta content="%7B%7D" name="profile-tetris/config/environment"/>
# <meta content="%7B%7D" name="publishing/config/environment"/>
# <meta content="%7B%7D" name="publishing-entity/config/environment"/>
# <meta content="%7B%7D" name="resume-builder/config/environment"/>
# <meta content="%7B%7D" name="salary-engine/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="search/config/environment"/>
# <meta content="%7B%7D" name="service-marketplace/config/environment"/>
# <meta content="%7B%7D" name="sharing-v2/config/environment"/>
# <meta content="%7B%7D" name="smp-service-pages/config/environment"/>
# <meta content="%7B%7D" name="tenor-gif/config/environment"/>
# <meta content="%7B%7D" name="unemployment/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="video-engine/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="video-go-live/config/environment"/>
# <meta content="%7B%7D" name="workflow/config/environment"/>
# <meta content="https://static-exp1.licdn.com/sc/h/c00rbckz4bb0q2l3vit7q6yfg" id="artdeco-icons/static/images/icons.svg" name="asset-url"/>
# <meta content='{"bundles":{"abi":{"assets":[{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/3wo4cajwewz5es55a16ls2927"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/ah3vrvd8ol27eb7i5vuq17h70"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/4eu6s0qxce7rwvhd0kvvfk4dq"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/8vfbd19159b5lufehign20sl5"}],"dependencies":[]},"article-reader":{"assets":[{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/6doc1sibmi0om14f3y82bdfah"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/boc71flkhei5uh516qno28542"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/27tlsg6y9s2a6l3bx03m02h2q"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/6wmb5o671k336odxfyed3nnei"}],"dependencies":["feed-shared"]},"career-services":{"assets":[{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/e986r6wc5o4rpppfvxtynined"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/60tujinxzzeihmv3tmeo348n3"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/ak2t5uugpguid5zbcbb7arxce"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/5ie7idfcewsg0sjumdgszasih"}],"dependencies":[]},"colleagues":{"assets":[{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/bncq1hcvt999ftx1a63vq41gl"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/c6q1cv1wsvx1l7ll8e6dsf19p"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/b8nbfzr3vejtdcsfc78nkmddu"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/3j6x1leg369w7sh4lpse6yiy8"}],"dependencies":[]},"company-creation":{"assets":[{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/6719fj416r0co17irp3h1paib"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/834lzwd9dhlt2rddlfi8fg7ku"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/cqit166njrky8099iohmmfart"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/474up9qvpqdbytertf7wf39gs"}],"dependencies":[]},"content-analytics":{"assets":[],"dependencies":null},"discover-tab":{"assets":[{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/cjfb77rv99ylbikjyqadts99p"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/bbo4ivg96xs48aroz08appjnc"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/2ruwgj4dd1gp18c18mkmjo4q2"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/bn6gue0e73tu96gbejhy13ny1"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/2ksz8hb4b1iqg3kjqs5jmtadr"}],"dependencies":["feed-shared"]},"emoji-picker":{"assets":[{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/coa7f3ykpl4n59lxspa6n42h5"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/8yau2s960jt29qv0l9kehasss"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/7zoioh3hzc76n91id19tp5p6p"}],"dependencies":null},"events-analytics":{"assets":[{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/8asccl3nu79eoj3yzzibycbmd"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/exb7bd6e6bqikdpkn0xlzqckk"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/d5u9lr7ylapvlga0yp83xjlg3"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/3owse4vf2v4xai1dblytapyw3"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/2ksz8hb4b1iqg3kjqs5jmtadr"}],"dependencies":[]},"events-networking-tables":{"assets":[{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/7zy4r2gzcuuk0rd1dh6q1yenf"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/6xb2qhjknpzdh2qn6beftem2h"}],"dependencies":[]},"events":{"assets":[{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/2xiw81b23eogfcq71imw51xro"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/2zafr0k91z77ugj659okp55xq"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/1etp934izkz9j6svdfurmll1g"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/ar29mnnlaoa5oh1r56l4axnlv"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/2ksz8hb4b1iqg3kjqs5jmtadr"}],"dependencies":["feed-shared"]},"feed-detail":{"assets":[{"type":"js","uri":"https://static-exp1.licdn.co ...
# <link href="https://static-exp1.licdn.com/sc/h/9fwggwzj4ry67lezk8lbio8ee" rel="stylesheet"/><link href="https://static-exp1.licdn.com/sc/h/6u1ng1mt1d680mhy7sd2kv0oh" rel="stylesheet"/><link href="https://static-exp1.licdn.com/sc/h/4r329lzx84o96sj1tymsq41l0" rel="stylesheet"/><link href="https://static-exp1.licdn.com/sc/h/dxobs0qdtbm86pw8xxexzm7jm" rel="stylesheet"/>
# <link class="lazy-css" href="https://static-exp1.licdn.com/sc/h/dbqfw5rio435iartemiz4wxkw" rel="stylesheet"/>
# <style></style>
# <script src="https://static-exp1.licdn.com/sc/h/9nblzu6rofyizrk18vuuu2ms5"></script><script src="https://static-exp1.licdn.com/sc/h/31z5yza1pff9yi7a5rv6knefa"></script><link href="https://static-exp1.licdn.com/sc/h/d367o9lqr30bqudltd0olpj3l" rel="stylesheet"/><script src="https://static-exp1.licdn.com/sc/h/1fkac6t6spnm0yzjzcoks0uyt"></script><link href="https://static-exp1.licdn.com/sc/h/bi3jmvaduc3iowkr8iutrq0bi" rel="stylesheet"/><script src="https://static-exp1.licdn.com/sc/h/8idtuc94ylmyekfkbezft55qo"></script><link href="https://static-exp1.licdn.com/sc/h/19httm1vj6cfipmnjlb1v5h8y" rel="stylesheet"/><script src="https://static-exp1.licdn.com/sc/h/aoqdl7juodon8gbr6ou2273l7"></script><script src="https://static-exp1.licdn.com/sc/h/3bhonqxxx4n4gooxgpaa9gvck"></script><link href="https://static-exp1.licdn.com/sc/h/6v0wmojtyi2cuk7aj5hnx4h13" rel="stylesheet"/><script src="https://static-exp1.licdn.com/sc/h/coa7f3ykpl4n59lxspa6n42h5"></script><script src="https://static-exp1.licdn.com/sc/h/6n1xt2ul6ix7ibmy2x724gd45"></script><link href="https://static-exp1.licdn.com/sc/h/8hvhcv8zq2zt8qcnvfmbr33lm" rel="stylesheet"/><script src="https://static-exp1.licdn.com/sc/h/41ymqcg33p0okhxqkyaoxs62k"></script><link href="https://static-exp1.licdn.com/sc/h/6dr7i6fyu5flxwi21xb0xmud5" rel="stylesheet"/><script src="https://static-exp1.licdn.com/sc/h/17v3jxcns05ntk3198mrktdx5"></script><link href="https://static-exp1.licdn.com/sc/h/el0wskzrfhz1csgfz083c6oqg" rel="stylesheet"/><script src="https://static-exp1.licdn.com/sc/h/a2cak8jwz0uxo99rd8gf2bjqf"></script><link href="https://static-exp1.licdn.com/sc/h/55e7wqtub3tqffwv77pqg3p3l" rel="stylesheet"/></head><body class="render-mode-BIGPIPE nav-v2 ember-application boot-complete icons-loaded" data-t-link-to-event-attached="true" dir="ltr"><meta content="app-id=288429040, affiliate-data=ct=campaign_vw_smart_app_banner&amp;pt=10746, app-argument=voyager://in/rishabh-singh-61b706114/?trk=vw_smart_app_banner" name="apple-itunes-app"/>
# <!-- HUED-11420 -->
# <div id="artdeco-toasts__wormhole"> <section class="artdeco-toasts" id="artdeco-toasts">
# <header class="artdeco-toasts__header">
# <h2 class="artdeco-toasts__title">
#         0 notifications total
#       </h2>
# </header>
# <!-- -->
# <ul class="artdeco-toasts_toasts">
# <!-- --> </ul>
# </section>
# </div>
# <div id="a11y-menu"></div><header class="extended-nav nav-main-container global-alert-offset-top hidden" data-test-main-nav="true" id="extended-nav" role="banner" style="pointer-events: none;" tabindex="-1"><div class="nav-main__content full-height display-flex align-items-center"><div class="nav-main__inbug-container"><div class="nav-item--inbug" id="inbug-nav-item" lang="en"><a class="nav-item__link js-nav-item-link" data-alias="" data-control-name="" data-link-to="feed" data-resource="feed/badge" href="/feed/"><span class="nav-item__icon nav-item__icon--inbug" lang="en" role="presentation"><li-icon aria-hidden="true" color="brand" size="34dp" type="linkedin-bug"><svg focusable="false" preserveaspectratio="xMinYMin meet" xmlns="http://www.w3.org/2000/svg"><g class="scaling-icon" style="fill-opacity: 1"><defs></defs><g class="bug-14dp" fill="none" fill-rule="evenodd" stroke="none" stroke-width="1"><g class="dp-1"><path class="bug-text-color" d="M14,1.25 L14,12.75 C14,13.44 13.44,14 12.75,14 L1.25,14 C0.56,14 0,13.44 0,12.75 L0,1.25 C0,0.56 0.56,0 1.25,0 L12.75,0 C13.44,0 14,0.56 14,1.25" fill="#FFFFFF"></path><path class="background" d="M14,1.25 L14,12.75 C14,13.44 13.44,14 12.75,14 L1.25,14 C0.56,14 0,13.44 0,12.75 L0,1.25 C0,0.56 0.56,0 1.25,0 L12.75,0 C13.44,0 14,0.56 14,1.25 Z M5,5 L6.85,5 L6.85,6.016 L6.893,6.016 C7.259,5.541 8.018,4.938 9.25,4.938 C11.125,4.938 12,5.808 12,8 L12,12 L10,12 L10,8.75 C10,7.313 9.672,6.875 8.632,6.875 C7.5,6.875 7,7.75 7,9 L7,12 L5,12 L5,5 Z M2,12 L4,12 L4,5 L2,5 L2,12 Z M4.335,3 C4.335,3.737 3.737,4.335 3,4.335 C2.263,4.335 1.665,3.737 1.665,3 C1.665,2.263 2.263,1.665 3,1.665 C3.737,1.665 4.335,2.263 4.335,3 Z" fill="#0073B2"></path></g><g class="dpi-gt1" transform="scale(0.2917)"><rect class="bug-text-color" fill="#FFFFFF" height="46" rx="4" width="46" x="1" y="1"></rect><path class="background" d="M0,4.00989318 C0,1.79529033 1.79405245,0 4.00989318,0 L43.9901068,0 C46.2047097,0 48,1.79405245 48,4.00989318 L48,43.9901068 C48,46.2047097 46.2059475,48 43.9901068,48 L4.00989318,48 C1.79529033,48 0,46.2059475 0,43.9901068 L0,4.00989318 Z M19,18.3 L25.5,18.3 L25.5,21.566 C26.437,19.688 28.838,18 32.445,18 C39.359,18 41,21.738 41,28.597 L41,41.3 L34,41.3 L34,30.159 C34,26.253 33.063,24.05 30.68,24.05 C27.375,24.05 26,26.425 26,30.159 L26,41.3 L19,41.3 L19,18.3 Z M7,41 L14,41 L14,18 L7,18 L7,41 Z M15,10.5 C15,12.985 12.985,15 10.5,15 C8.015,15 6,12.985 6,10.5 C6,8.015 8.015,6 10.5,6 C12.985,6 15,8.015 15,10.5 Z" fill="#0077B5"></path></g></g><g class="bug-21dp" fill="none" fill-rule="evenodd" stroke="none" stroke-width="1"><g class="dp-1"><path class="bug-text-color" d="M19.479,0 L1.583,0 C0.728,0 0,0.677 0,1.511 L0,19.488 C0,20.323 0.478,21 1.333,21 L19.229,21 C20.086,21 21,20.323 21,19.488 L21,1.511 C21,0.677 20.336,0 19.479,0" fill="#FFFFFF"></path><path class="background" d="M19.479,0 L1.583,0 C0.728,0 0,0.677 0,1.511 L0,19.488 C0,20.323 0.478,21 1.333,21 L19.229,21 C20.086,21 21,20.323 21,19.488 L21,1.511 C21,0.677 20.336,0 19.479,0 Z M8,8 L10.827,8 L10.827,9.441 L10.858,9.441 C11.289,8.664 12.562,7.875 14.136,7.875 C17.157,7.875 18,9.479 18,12.45 L18,18 L15,18 L15,12.997 C15,11.667 14.469,10.5 13.227,10.5 C11.719,10.5 11,11.521 11,13.197 L11,18 L8,18 L8,8 Z M3,18 L6,18 L6,8 L3,8 L3,18 Z M6.375,4.5 C6.375,5.536 5.536,6.375 4.5,6.375 C3.464,6.375 2.625,5.536 2.625,4.5 C2.625,3.464 3.464,2.625 4.5,2.625 C5.536,2.625 6.375,3.464 6.375,4.5 Z" fill="#0077B5"></path></g><g class="dpi-gt1" transform="scale(0.4375)"><rect class="bug-text-color" fill="#FFFFFF" height="46" rx="4" width="46" x="1" y="1"></rect><path class="background" d="M0,4.00989318 C0,1.79529033 1.79405245,0 4.00989318,0 L43.9901068,0 C46.2047097,0 48,1.79405245 48,4.00989318 L48,43.9901068 C48,46.2047097 46.2059475,48 43.9901068,48 L4.00989318,48 C1.79529033,48 0,46.2059475 0,43.9901068 L0,4.00989318 Z M19,18.3 L25.5,18.3 L25.5,21.566 C26.437,19.688 28.838,18 32.445,18 C39.359,18 41,21.738 41,28.597 L41,41.3 L34,41.3 L34,30.159 C3 ...
# <!-- EMBER_CLI_FASTBOOT_BODY -->
# <script data-fastboot-src="assets/polyfill-shared.js" src="https://static-exp1.licdn.com/sc/h/7lllmhir13652hrt9onk67idy"></script>
# <script data-fastboot-src="assets/polyfill-legacy.js" nomodule="" src="https://static-exp1.licdn.com/sc/h/6q09pst6bmsj619gq1d05p63l"></script>
# <script data-fastboot-src="assets/polyfill-evergreen.js" src="https://static-exp1.licdn.com/sc/h/a8q6glm6zvu7gvt3mhab9x3zv"></script>
# <div class="app-boot-bg-skeleton" id="app-boot-bg-loader">
# <div class="top-bar"></div>
# <div class="content">
# <div class="initial-load-animation fade-load">
# <div class="linkedin-image display-flex justify-center">
# <svg class="hidden-in-classic" height="48" viewbox="0 0 190 48" width="190" xmlns="http://www.w3.org/2000/svg">
# <g>
# <g>
# <path d="M58,27.22V41H51V28.88c0-3.7-2.07-5.24-4-5.24a5,5,0,0,0-5.14,4.85,4.34,4.34,0,0,0,0,.51V41H35V18h6.6v3.25h.09c.69-1.41,3.64-3.75,7.66-3.75S58,20.22,58,27.22ZM24,41h7V18H24ZM27.5,6.45a4.05,4.05,0,1,0,4.1,4.05,4,4,0,0,0-4-4ZM190,3.5v41a3.5,3.5,0,0,1-3.5,3.5h-41a3.5,3.5,0,0,1-3.5-3.5V3.5A3.5,3.5,0,0,1,145.5,0h41A3.5,3.5,0,0,1,190,3.5ZM156,18h-7V41h7Zm.6-7.5a4.1,4.1,0,1,0-4.15,4.05h.05a4,4,0,0,0,4.1-3.9ZM183,27.22c0-7-4.63-9.72-8.65-9.72s-7,2.34-7.66,3.75h-.09V18H160V41h7V29c0-3.69,2.51-5.33,4.95-5.33,2,0,4.05,1.54,4.05,5.24V41h7ZM8,7H0V41H21V34H8ZM108,29.77v2H91a1.33,1.33,0,0,0,.11.43c.58,1.93,2.67,3.56,5.75,3.56A6.3,6.3,0,0,0,102,33.52l5.1,3.18a12.72,12.72,0,0,1-10.45,4.8C89.94,41.5,84,37.42,84,29.59S90,17.5,96.44,17.5,108,21.81,108,29.77ZM101,27c0-2.4-1.56-4.38-4.75-4.38-3,0-5.09,2-5.25,4.38ZM85.26,18H76.68l-7.54,9.37H69V7H62V41h7V30h.14l7.72,11h8.77L76.2,28.43ZM128,7h7V41h-6.6V38h-.09c-.88,1.52-3.24,3.49-7.4,3.49-5,0-10.91-3.63-10.91-12,0-7.53,5.1-11.95,10.82-11.95a9.55,9.55,0,0,1,7.09,3H128Zm.3,22.49a5.74,5.74,0,0,0-5.59-5.89h-.15A5.54,5.54,0,0,0,116.89,29c0,.15,0,.29,0,.44a5.61,5.61,0,0,0,5.26,5.94h.4A5.83,5.83,0,0,0,128.3,29.49Z" style="fill: #0a66c2"></path>
# </g>
# </g>
# </svg>
# <li-icon aria-hidden="true" class="hidden-in-mercado" color="brand" size="48dp" type="linkedin-bug"><svg focusable="false" preserveaspectratio="xMinYMin meet" xmlns="http://www.w3.org/2000/svg"><g class="scaling-icon" style="fill-opacity: 1"><defs></defs><g class="bug-14dp" fill="none" fill-rule="evenodd" stroke="none" stroke-width="1"><g class="dp-1"><path class="bug-text-color" d="M14,1.25 L14,12.75 C14,13.44 13.44,14 12.75,14 L1.25,14 C0.56,14 0,13.44 0,12.75 L0,1.25 C0,0.56 0.56,0 1.25,0 L12.75,0 C13.44,0 14,0.56 14,1.25" fill="#FFFFFF"></path><path class="background" d="M14,1.25 L14,12.75 C14,13.44 13.44,14 12.75,14 L1.25,14 C0.56,14 0,13.44 0,12.75 L0,1.25 C0,0.56 0.56,0 1.25,0 L12.75,0 C13.44,0 14,0.56 14,1.25 Z M5,5 L6.85,5 L6.85,6.016 L6.893,6.016 C7.259,5.541 8.018,4.938 9.25,4.938 C11.125,4.938 12,5.808 12,8 L12,12 L10,12 L10,8.75 C10,7.313 9.672,6.875 8.632,6.875 C7.5,6.875 7,7.75 7,9 L7,12 L5,12 L5,5 Z M2,12 L4,12 L4,5 L2,5 L2,12 Z M4.335,3 C4.335,3.737 3.737,4.335 3,4.335 C2.263,4.335 1.665,3.737 1.665,3 C1.665,2.263 2.263,1.665 3,1.665 C3.737,1.665 4.335,2.263 4.335,3 Z" fill="#0073B2"></path></g><g class="dpi-gt1" transform="scale(0.2917)"><rect class="bug-text-color" fill="#FFFFFF" height="46" rx="4" width="46" x="1" y="1"></rect><path class="background" d="M0,4.00989318 C0,1.79529033 1.79405245,0 4.00989318,0 L43.9901068,0 C46.2047097,0 48,1.79405245 48,4.00989318 L48,43.9901068 C48,46.2047097 46.2059475,48 43.9901068,48 L4.00989318,48 C1.79529033,48 0,46.2059475 0,43.9901068 L0,4.00989318 Z M19,18.3 L25.5,18.3 L25.5,21.566 C26.437,19.688 28.838,18 32.445,18 C39.359,18 41,21.738 41,28.597 L41,41.3 L34,41.3 L34,30.159 C34,26.253 33.063,24.05 30.68,24.05 C27.375,24.05 26,26.425 26,30.159 L26,41.3 L19,41.3 L19,18.3 Z M7,41 L14,41 L14,18 L7,18 L7,41 Z M15,10.5 C15,12.985 12.985,15 10.5,15 C8.015,15 6,12.985 6,10.5 C6,8.015 8.015,6 10.5,6 C12.985,6 15,8.015 15,10.5 Z" fill="#0077B5"></path></g></g><g class="bug-21dp" fill="none" fill-rule="evenodd" stroke="none" stroke-width="1"><g class="dp-1"><path class="bug-text-color" d="M19.479,0 L1.583,0 C0.728,0 0,0.677 0,1.511 L0,19.488 C0,20.323 0.478,21 1.333,21 L19.229,21 C20.086,21 21,20.323 21,19.488 L21,1.511 C21,0.677 20.336,0 19.479,0" fill="#FFFFFF"></path><path class="background" d="M19.479,0 L1.583,0 C0.728,0 0,0.677 0,1.511 L0,19.488 C0,20.323 0.478,21 1.333,21 L19.229,21 C20.086,21 21,20.323 21,19.488 L21,1.511 C21,0.677 20.336,0 19.479,0 Z M8,8 L10.827,8 L10.827,9.441 L10.858,9.441 C11.289,8.664 12.562,7.875 14.136,7.875 C17.157,7.875 18,9.479 18,12.45 L18,18 L15,18 L15,12.997 C15,11.667 14.469,10.5 13.227,10.5 C11.719,10.5 11,11.521 11,13.197 L11,18 L8,18 L8,8 Z M3,18 L6,18 L6,8 L3,8 L3,18 Z M6.375,4.5 C6.375,5.536 5.536,6.375 4.5,6.375 C3.464,6.375 2.625,5.536 2.625,4.5 C2.625,3.464 3.464,2.625 4.5,2.625 C5.536,2.625 6.375,3.464 6.375,4.5 Z" fill="#0077B5"></path></g><g class="dpi-gt1" transform="scale(0.4375)"><rect class="bug-text-color" fill="#FFFFFF" height="46" rx="4" width="46" x="1" y="1"></rect><path class="background" d="M0,4.00989318 C0,1.79529033 1.79405245,0 4.00989318,0 L43.9901068,0 C46.2047097,0 48,1.79405245 48,4.00989318 L48,43.9901068 C48,46.2047097 46.2059475,48 43.9901068,48 L4.00989318,48 C1.79529033,48 0,46.2059475 0,43.9901068 L0,4.00989318 Z M19,18.3 L25.5,18.3 L25.5,21.566 C26.437,19.688 28.838,18 32.445,18 C39.359,18 41,21.738 41,28.597 L41,41.3 L34,41.3 L34,30.159 C34,26.253 33.063,24.05 30.68,24.05 C27.375,24.05 26,26.425 26,30.159 L26,41.3 L19,41.3 L19,18.3 Z M7,41 L14,41 L14,18 L7,18 L7,41 Z M15,10.5 C15,12.985 12.985,15 10.5,15 C8.015,15 6,12.985 6,10.5 C6,8.015 8.015,6 10.5,6 C12.985,6 15,8.015 15,10.5 Z" fill="#0077B5"></path></g></g><g class="bug-28dp" fill="none" fill-rule="evenodd" stroke="none" stroke-width="1"><g class="dp-1"><path class="bug-text-color" d="M25.375,0 L2.625,0 C1.175,0 0,1.175 0,2.625 L0,25.375 C0,26.825 1.175,28 2.625,28 L25.375,28 C26.825,28 28,26.825 28,25.375 L28,2.625 C28,1.175 26.825,0 25.375,0" f ...
# </div>
# <div class="loading-bar">
# <div class="blue-bar"></div>
# </div>
# </div>
# </div>
# </div>
# <script crossorigin="" data-fastboot-src="assets/vendor-static.js" src="https://static-exp1.licdn.com/sc/h/2p04274v4btc9m0bubd707hxf"></script>
# <script crossorigin="" data-fastboot-src="assets/vendor.js" src="https://static-exp1.licdn.com/sc/h/cttf2hxe91ala1fu31tsggiih"></script>
# <script crossorigin="" data-fastboot-src="assets/i18n/support_en_US.js" src="https://static-exp1.licdn.com/sc/h/37x02boc40ul7yo7s8v7zs50x"></script>
# <script src="https://static-exp1.licdn.com/sc/h/e87j1uz669ahlrry0j0bsna0w"></script><script src="https://static-exp1.licdn.com/sc/h/be7t3n4lfnslrh07krosmavr6"></script><script src="https://static-exp1.licdn.com/sc/h/2ksz8hb4b1iqg3kjqs5jmtadr"></script><script src="https://static-exp1.licdn.com/sc/h/4vcekdcm18li6xge44ozykvqp"></script><script src="https://static-exp1.licdn.com/sc/h/31dj612xkzevqex2ampp6gtxf"></script>
# <script crossorigin="" data-fastboot-src="assets/extended.js" src="https://static-exp1.licdn.com/sc/h/bhcutytzegjwxanr5rusufopx"></script>
# <div id="artdeco-modal-outlet"></div>
# <code id="bpr-guid-807958" style="display: none">
#   {"data":{"entityUrn":"urn:li:collectionResponse:ScMTp1U8ZzdSe6vWTqP4cfx6uFl/LZqcspOImGFcReM=","paging":{"start":0,"count":10,"links":[],"$recipeTypes":["com.linkedin.voyager.dash.deco.common.FullPaging"]},"*elements":["urn:li:fsd_notificationSegment:NEW","urn:li:fsd_notificationSegment:EARLIER"],"$type":"com.linkedin.restli.common.CollectionResponse"},"meta":{"microSchema":{"version":"2","types":{"com.linkedin.voyager.dash.deco.identity.notifications.FullCardAction":{"fields":{"displayText":{"type":"com.linkedin.voyager.dash.deco.common.text.TextViewModelV2"},"memberToConnectUrn":{"type":"string"},"reloadCard":{"type":"boolean"},"signature":{"type":"string"},"followingStateUrn":{"type":"string"},"confirmationText":{"type":"com.linkedin.voyager.dash.deco.common.text.TextViewModelV2"},"afterActionTarget":{"type":"string"},"actionTarget":{"type":"string"},"type":{"type":"string"},"primary":{"type":"boolean"}},"baseType":"com.linkedin.voyager.dash.identity.notifications.CardAction"},"com.linkedin.voyager.dash.deco.common.text.TextViewModelV2":{"fields":{"textDirection":{"type":"string"},"text":{"type":"string"},"attributesV2":{"type":{"array":"com.linkedin.voyager.dash.deco.common.text.TextAttributeV2"}},"accessibilityTextAttributesV2":{"type":{"array":"com.linkedin.voyager.dash.deco.common.text.TextAttributeV2"}},"accessibilityText":{"type":"string"}},"baseType":"com.linkedin.voyager.dash.common.text.TextViewModel"},"com.linkedin.deco.recipe.anonymous.Anon1529112441":{"fields":{"originalImageUrl":{"type":"string"},"originalHeight":{"type":"int"},"url":{"type":"string"},"originalWidth":{"type":"int"}},"baseType":"com.linkedin.voyager.dash.common.ImageUrl"},"com.linkedin.deco.recipe.anonymous.Anon1251747613":{"fields":{"urn":{"type":"string"},"modelName":{"type":"string"},"fieldName":{"type":"string"},"value":{"type":"string"}},"baseType":"com.linkedin.voyager.dash.common.StringFieldReference"},"com.linkedin.voyager.dash.deco.common.image.ProfileWithoutFrame":{"fields":{"profilePicture":{"type":"com.linkedin.voyager.dash.deco.common.image.PhotoFilterPicture"},"entityUrn":{"type":"string"}},"baseType":"com.linkedin.voyager.dash.identity.profile.Profile"},"com.linkedin.voyager.dash.deco.identity.notifications.SocialActivityCounts":{"fields":{"urn":{"type":"string"},"numComments":{"type":"long"},"numLikes":{"type":"long"},"entityUrn":{"type":"string"},"liked":{"type":"boolean"}},"baseType":"com.linkedin.voyager.dash.feed.SocialActivityCounts"},"com.linkedin.deco.recipe.anonymous.Anon1467087198":{"fields":{"vectorImage":{"type":"com.linkedin.voyager.dash.deco.common.image.VectorImage"},"professionalEventUrn":{"type":"string"}},"baseType":"com.linkedin.voyager.dash.common.image.NonEntityProfessionalEventLogo"},"com.linkedin.voyager.dash.deco.common.image.Company":{"fields":{"logo":{"type":{"union":{"url":"string","vectorImage":"com.linkedin.voyager.dash.deco.common.image.VectorImage"}}},"entityUrn":{"type":"string"}},"baseType":"com.linkedin.voyager.dash.organization.Company"},"com.linkedin.voyager.dash.deco.common.text.ProfileForFullName":{"fields":{"lastName":{"type":"string"},"firstName":{"type":"string"},"entityUrn":{"type":"string"}},"baseType":"com.linkedin.voyager.dash.identity.profile.Profile"},"com.linkedin.voyager.dash.deco.common.image.Profile":{"fields":{"profilePicture":{"type":"com.linkedin.voyager.dash.deco.common.image.PhotoFilterPicture"},"entityUrn":{"type":"string"}},"baseType":"com.linkedin.voyager.dash.identity.profile.Profile"},"com.linkedin.voyager.dash.deco.common.text.JobPosting":{"fields":{"title":{"type":"string"},"entityUrn":{"type":"string"}},"baseType":"com.linkedin.voyager.dash.jobs.JobPosting"},"com.linkedin.deco.recipe.anonymous.Anon2022772393":{"fields":{"profileUrn":{"type":"string"},"vectorImage":{"type":"com.linkedin.voyager.dash.deco.common.image.VectorImage"}},"baseType":"com.linkedin.voyager.dash.common.image.NonEntityProfilePicture"},"com.linkedin.deco.recipe.anonymous.Anon673822800":{"fields": ...
# </code>
# <code id="datalet-bpr-guid-807958" style="display: none">
#   {"request":"/voyager/api/notifications/dash/segments?decorationId\u003Dcom.linkedin.voyager.dash.deco.identity.notifications.SegmentCollectionWithCards-35","status":200,"body":"bpr-guid-807958","method":"GET"}
# </code>
# <img class="datalet-bpr-guid-807958" src="..." style="display: none"/><code id="bpr-guid-807959" style="display: none">
#   {"data":{"entityUrn":"urn:li:collectionResponse:nZx6/1e1AAbOHh075gv083zrunZT186/K+rx5FP70A4=","elements":[],"paging":{"count":10,"start":0,"links":[]},"$type":"com.linkedin.restli.common.CollectionResponse"},"included":[]}
# </code>
# <code id="datalet-bpr-guid-807959" style="display: none">
#   {"request":"/voyager/api/chameleonConfig","status":200,"body":"bpr-guid-807959","method":"GET"}
# </code>
# <img class="datalet-bpr-guid-807959" src="..." style="display: none"/><code id="bpr-guid-807960" style="display: none">
#   {"data":{"entityUrn":"urn:li:collectionResponse:uPYuDSPXzooiHx+zPOguG1+f+JFMWTWFEfhiIQtEFMM=","elements":[],"paging":{"count":10,"start":0,"total":0,"links":[]},"$type":"com.linkedin.restli.common.CollectionResponse"},"included":[]}
# </code>
# <code id="datalet-bpr-guid-807960" style="display: none">
#   {"request":"/voyager/api/takeovers","status":200,"body":"bpr-guid-807960","method":"GET"}
# </code>
# <img class="datalet-bpr-guid-807960" src="..." style="display: none"/><code id="bpr-guid-807961" style="display: none">
# ...
# </a> </li>
# <li class="grid__col grid__col--8 mb1">
# <div class="ember-view" id="ember350"><div class="global-footer-dropdown artdeco-dropdown artdeco-dropdown--placement-top artdeco-dropdown--justification-left ember-view" id="ember351"><button aria-expanded="false" class="global-footer-dropdown__trigger artdeco-dropdown__trigger artdeco-dropdown__trigger--placement-top ember-view" data-control-name="globalfooter.privacy" id="globalfooter-privacy_dropdown-trigger" tabindex="0" type="button"> <span class="global-footer__link global-footer__link--static t-12 t-bold">
#       Privacy &amp; Terms
#       <li-icon aria-hidden="true" class="global-footer-dropdown__trigger-icon" size="small" type="chevron-down-icon"><svg class="mercado-match" data-supported-dps="16x16" fill="currentColor" focusable="false" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
# <path d="M1 5l7 4.61L15 5v2.39L8 12 1 7.39z"></path>
# </svg></li-icon>
# </span>
# <!-- --></button><div aria-hidden="true" class="global-footer-dropdown__options artdeco-dropdown__content artdeco-dropdown--is-dropdown-element artdeco-dropdown__content--justification-left artdeco-dropdown__content--placement-top ember-view" id="ember353" tabindex="-1"><!-- --></div></div></div>
# </li>
# <li class="grid__col grid__col--8 mb1">
# <a class="global-footer__link global-footer__link--static t-12 t-bold ember-view" data-control-name="globalfooter.ad_choices" href="https://www.linkedin.com/help/linkedin/answer/62931" id="globalfooter-ad_choices" rel="noopener noreferrer" tabindex="0" target="_blank">                    Ad Choices
# </a> </li>
# <li class="grid__col grid__col--8 mb1">
# <a class="global-footer__link global-footer__link--static t-12 t-bold ember-view" data-control-name="globalfooter.advertising" href="https://www.linkedin.com/ad/start?trk=n_nav_ads_f" id="globalfooter-advertising" rel="noopener noreferrer" tabindex="0" target="_blank">                    Advertising
# </a> </li>
# <li class="grid__col grid__col--8 mb1">
# <a class="global-footer__link global-footer__link--static t-12 t-bold ember-view" data-control-name="globalfooter.sales_solutions" href="https://business.linkedin.com/sales-solutions?trk=flagship_nav&amp;veh=li-footer-lss-control&amp;src=li-footer" id="globalfooter-sales_solutions" rel="noopener noreferrer" tabindex="0" target="_blank">                    Sales Solutions
# </a> </li>
# <li class="grid__col grid__col--8 mb1">
# <a class="global-footer__link global-footer__link--static t-12 t-bold ember-view" data-control-name="globalfooter.mobile" href="https://mobile.linkedin.com/" id="globalfooter-mobile" rel="noopener noreferrer" tabindex="0" target="_blank">                    Mobile
# </a> </li>
# <li class="grid__col grid__col--8 mb1">
# <a class="global-footer__link global-footer__link--static t-12 t-bold ember-view" data-control-name="globalfooter.small_business" href="https://smallbusiness.linkedin.com?&amp;src=li-footer" id="globalfooter-small_business" rel="noopener noreferrer" tabindex="0" target="_blank">                    Small Business
# </a> </li>
# <li class="grid__col grid__col--8 mb1">
# <a class="global-footer__link global-footer__link--static t-12 t-bold ember-view" data-control-name="globalfooter.safety_center" href="https://safety.linkedin.com" id="globalfooter-safety_center" rel="noopener noreferrer" tabindex="0" target="_blank">                    Safety Center
# </a> </li>
# </ul>
# </nav>
# <ul class="grid__col grid__col--6" id="footer-action-list">
# <li class="display-flex list-style-none mb4">
# <li-icon active="true" aria-hidden="true" class="global-footer__action-icon" color="true" type="question-pebble-icon"><svg class="mercado-match" data-supported-dps="24x24" fill="currentColor" focusable="false" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M12 2a10 10 0 1010 10A10 10 0 0012 2zm0 16.25A1.25 1.25 0 1113.25 17 1.25 1.25 0 0112 18.25zm1.41-5.46L13 13v1h-2v-2.21l1.49-.79C13.82 10.34 14 9.77 14 9.3c0-.78-.92-1.3-2.3-1.3A7.12 7.12 0 008 9.24V7a8 8 0 013.7-1c3 0 4.3 1.55 4.3 3.3a3.91 3.91 0 01-2.59 3.49z"></path>
# </svg></li-icon>
# <span>
# <a class="global-footer__link global-footer__link--static t-14 t-bold ember-view" data-control-name="globalfooter.questions" href="https://www.linkedin.com/help/linkedin?trk=d_flagship3_profile_view_base" id="globalfooter-questions" rel="noopener noreferrer" tabindex="0" target="_blank">                    Questions?
# </a>
# <p class="global-footer__label t-12">Visit our Help Center.</p>
# </span>
# </li>
# <li class="display-flex list-style-none mb4">
# <li-icon active="true" aria-hidden="true" class="global-footer__action-icon" color="true" type="gear-icon"><svg class="mercado-match" data-supported-dps="24x24" fill="currentColor" focusable="false" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M9.18 2l-4.3 2.52L6.22 8l-.52.91-3.7.55v5l3.64.54.54.93-1.34 3.53L9.14 22l2.29-2.9h1.09l2.3 2.9 4.32-2.52L17.79 16l.53-.93 3.68-.53v-5L18.32 9l-.51-.9 1.36-3.51L14.86 2l-2.33 3h-1zM12 9a3 3 0 11-3 3 3 3 0 013-3z"></path>
# </svg></li-icon>
# <span>
# <a class="global-footer__link global-footer__link--static t-14 t-bold ember-view" data-control-name="globalfooter.manage_account" href="https://www.linkedin.com/psettings/" id="globalfooter-manage_account" rel="noopener noreferrer" tabindex="0" target="_blank">                    Manage your account and privacy
# </a>
# <p class="global-footer__label t-12">Go to your Settings.</p>
# </span>
# </li>
# </ul>
# <div class="grid__col grid__col--6">
# <label class="global-footer__label t-12 t-normal mb1 mt0" for="globalfooter-select_language">
#             Select Language
#           </label>
# <select class="global-footer__language-selection-dropdown t-12 t-black--light t-bold" id="globalfooter-select_language">
# <option lang="ar-ae" value="ar_AE">العربية (Arabic)</option>
# <option lang="cs-cz" value="cs_CZ">Čeština (Czech)</option>
# <option lang="da-dk" value="da_DK">Dansk (Danish)</option>
# <option lang="de-de" value="de_DE">Deutsch (German)</option>
# <option lang="en-us" value="en_US">English (English)</option>
# <option lang="es-es" value="es_ES">Español (Spanish)</option>
# <option lang="fr-fr" value="fr_FR">Français (French)</option>
# <option lang="in-id" value="in_ID">Bahasa Indonesia (Bahasa Indonesia)</option>
# <option lang="it-it" value="it_IT">Italiano (Italian)</option>
# <option lang="ja-jp" value="ja_JP">日本語 (Japanese)</option>
# <option lang="ko-kr" value="ko_KR">한국어 (Korean)</option>
# <option lang="ms-my" value="ms_MY">Bahasa Malaysia (Malay)</option>
# <option lang="nl-nl" value="nl_NL">Nederlands (Dutch)</option>
# <option lang="no-no" value="no_NO">Norsk (Norwegian)</option>
# <option lang="pl-pl" value="pl_PL">Polski (Polish)</option>
# <option lang="pt-br" value="pt_BR">Português (Portuguese)</option>
# <option lang="ro-ro" value="ro_RO">Română (Romanian)</option>
# <option lang="ru-ru" value="ru_RU">Русский (Russian)</option>
# <option lang="sv-se" value="sv_SE">Svenska (Swedish)</option>
# <option lang="th-th" value="th_TH">ภาษาไทย (Thai)</option>
# <option lang="tl-ph" value="tl_PH">Tagalog (Tagalog)</option>
# <option lang="tr-tr" value="tr_TR">Türkçe (Turkish)</option>
# <option lang="zh-cn" value="zh_CN">简体中文 (Chinese (Simplified))</option>
# <option lang="zh-tw" value="zh_TW">正體中文 (Chinese (Traditional))</option>
# </select>
# </div>
# </div>
# <p class="t-12 t-black--light t-normal text-align-left clear-both" id="globalfooter-copyright">
#         LinkedIn Corporation © 2020
#       </p>
# </div>
# </div></footer>
# </div>
# </div>
# <!-- -->
# <!-- -->
# </div>
# </div>
# </div>
# </div>
# <aside class="msg-overlay-container ember-view" id="msg-overlay"><!-- -->
# <div class="msg-overlay-list-bubble ml4" tabindex="-1">
# <header class="msg-overlay-bubble-header" data-control-name="overlay.minimize_connection_list_bar" data-ember-action="" data-ember-action-107="107">
# <!-- -->
# <section class="msg-overlay-bubble-header__details flex-row align-items-center">
# <div class="presence-entity presence-entity--size-1 ember-view" id="ember108"><img alt="Arjun Arjun" class="presence-entity__image EntityPhoto-circle-1 lazy-image ghost-person ember-view" id="ember109" loading="" src="..." title="Arjun Arjun"/>
# <div class="presence-entity__indicator presence-entity__indicator--size-1 presence-indicator presence-indicator--is-online presence-indicator--size-1 ember-view" id="ember110">
# <span class="visually-hidden">
#     Status is online
# </span></div></div>
# <button class="msg-overlay-bubble-header__button truncate ml2" type="button">
# <h4 class="truncate t-14 t-bold t-black">
# <span aria-hidden="true">
#             Messaging
#           </span>
# <span class="visually-hidden">
#             You are on the messaging overlay. Press enter to minimize it.
#           </span>
# </h4>
# </button>
# <!-- --><!-- --> </section>
# <section class="msg-overlay-bubble-header__controls display-flex">
# <button class="msg-overlay-bubble-header__control msg-overlay-bubble-header__control--new-convo-btn artdeco-button artdeco-button--circle artdeco-button--muted artdeco-button--1 artdeco-button--tertiary ember-view" data-control-name="overlay.compose_message" id="ember111"> <li-icon aria-hidden="true" class="artdeco-button__icon" size="small" type="compose-icon"><svg class="mercado-match" data-supported-dps="16x16" fill="currentColor" focusable="false" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
# <path d="M15 2.53a1.51 1.51 0 01-.44 1L9.15 9 6 10l1-3.12 5.44-5.44A1.5 1.5 0 0115 2.53zM12 11a1 1 0 01-1 1H5a1 1 0 01-1-1V5a1 1 0 011-1h3V2H5a3 3 0 00-3 3v6a3 3 0 003 3h6a3 3 0 003-3V8h-2z"></path>
# </svg></li-icon>
# <span class="artdeco-button__text">
#     Compose message
# </span></button>
# <div class="artdeco-dropdown artdeco-dropdown--placement-bottom artdeco-dropdown--justification-right ember-view" id="ember112">
# <button aria-expanded="false" class="artdeco-button artdeco-button--1 artdeco-button--circle artdeco-button--tertiary artdeco-button--muted artdeco-dropdown__trigger artdeco-dropdown__trigger--placement-bottom ember-view" data-control-name="overlay.dropdown_menu" id="ember113" tabindex="0" type="button">
# <li-icon aria-label="Open messenger dropdown menu" color="true" role="img" size="small" type="ellipsis-horizontal-icon"><svg class="mercado-match" data-supported-dps="16x16" fill="currentColor" focusable="false" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
# <path d="M3 9.5A1.5 1.5 0 114.5 8 1.5 1.5 0 013 9.5zM11.5 8A1.5 1.5 0 1013 6.5 1.5 1.5 0 0011.5 8zm-5 0A1.5 1.5 0 108 6.5 1.5 1.5 0 006.5 8z"></path>
# </svg></li-icon>
# <!-- --></button>
# <div class="msg-overlay-bubble-header__dropdown-container">
# <div aria-hidden="true" class="artdeco-dropdown__content artdeco-dropdown--is-dropdown-element artdeco-dropdown__content--has-arrow artdeco-dropdown__content--arrow-right artdeco-dropdown__content--justification-right artdeco-dropdown__content--placement-bottom ember-view" id="ember114" tabindex="-1"><!-- --></div>
# </div>
# </div>
# <!-- -->
# <button class="msg-overlay-bubble-header__control msg-overlay-bubble-header__control--new-convo-btn artdeco-button artdeco-button--circle artdeco-button--muted artdeco-button--1 artdeco-button--tertiary ember-view" id="ember115"> <li-icon aria-hidden="true" class="artdeco-button__icon" size="small" type="chevron-down-icon"><svg class="mercado-match" data-supported-dps="16x16" fill="currentColor" focusable="false" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
# <path d="M1 5l7 4.61L15 5v2.39L8 12 1 7.39z"></path>
# </svg></li-icon>
# <span class="artdeco-button__text">
#     You are on the messaging overlay. Press enter to minimize it.
# </span></button>
# </section>
# </header>
# <!-- -->
# <div class="msg-overlay-list-bubble-search ember-view" id="ember183"> <div class="msg-overlay-list-bubble-search__input-container">
# <label class="a11y-text" for="msg-overlay-list-bubble-search__search-typeahead-input">
#     Type to search for connections and conversations.
#   </label>
# <li-icon aria-hidden="true" class="msg-overlay-list-search__search-icon" size="small" type="search-icon"><svg class="mercado-match" data-supported-dps="16x16" fill="currentColor" focusable="false" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
# <path d="M14.56 12.44L11.3 9.18a5.51 5.51 0 10-2.12 2.12l3.26 3.26a1.5 1.5 0 102.12-2.12zM3 6.5A3.5 3.5 0 116.5 10 3.5 3.5 0 013 6.5z"></path>
# </svg></li-icon>
# <input autocomplete="off" class="msg-overlay-list-bubble-search__search-typeahead-input ember-text-field ember-view" id="msg-overlay-list-bubble-search__search-typeahead-input" placeholder="Search messages" type="text"/>
# <div class="msg-overlay-list-bubble__filters-dropdown artdeco-dropdown artdeco-dropdown--placement-bottom artdeco-dropdown--justification-right ember-view" id="ember185">
# <button aria-expanded="false" class="msg-overlay-list-bubble__filters-btn artdeco-dropdown__trigger artdeco-dropdown__trigger--placement-bottom ember-view" id="ember186" tabindex="0" type="button">
# <!-- --> <li-icon aria-label="Filter messages by" role="img" size="small" type="filter-icon"><svg data-supported-dps="16x16" fill="currentColor" focusable="false" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
# <path d="M15 2v2H6.72a2 2 0 01-3.44 0H1V2h2.28a2 2 0 013.44 0H15zm-4 4a2 2 0 00-1.72 1H1v2h8.28a2 2 0 003.45 0H15V7h-2.28A2 2 0 0011 6zm-6 5a2 2 0 00-1.72 1H1v2h2.28a2 2 0 003.45 0H15v-2H6.72A2 2 0 005 11z"></path>
# </svg></li-icon>
# <!-- --></button>
# <div aria-hidden="true" class="artdeco-dropdown__content msg-overlay-list-bubble__filters-dropdown-content artdeco-dropdown--is-dropdown-element artdeco-dropdown__content--has-arrow artdeco-dropdown__content--arrow-right artdeco-dropdown__content--justification-right artdeco-dropdown__content--placement-bottom ember-view" id="ember187" tabindex="-1"><!-- --></div>
# </div>
# </div>
# <!-- -->
# <!-- --><!-- --><div class="msg-overlay-list-bubble-search-content hidden">
# <div class="msg-overlay-list-bubble-search__history-placeholder-container text-align-center">
# <div class="msg-overlay-list-bubble__illustration msg-overlay-list-bubble-search__history-placeholder-illustration"></div>
# <p class="t-14 t-black t-normal ph2">
#             Search your messages by recipient, content, or conversation name
#           </p>
# </div>
# </div></div>
# <!-- -->
# <!-- -->
# <!-- -->
# <!-- -->
# <!-- -->
# <section class="scrollable msg-overlay-list-bubble__content msg-overlay-list-bubble__content--scrollable">
# <div class="msg-overlay-list-bubble-default-conversation-container">
# <div class="msg-overlay-abi text-align-center ph6">
# <div class="msg-overlay-list-bubble__illustration msg-overlay-abi__illustration"></div>
# <h4 class="t-16 t-black t-bold">
#       Keep in touch with your network
#     </h4>
# <p class="t-14 t-black--light t-normal mt3 mb3">
#       Start a conversation with your connections or find new people to grow your network.
#     </p>
# <a class="msg-overlay-abi__find-new-connections t-14 ember-view" href="/mynetwork/import-contacts/" id="ember294">
#       Find new connections
#     </a>
# </div>
# <!-- --> </div>
# </section>
# <!-- --><!-- --></div>
# <!-- -->
# <div id="msg-overlay__emoji-hoverable-outlet"></div></aside>
# <img class="third-party-tracking-pixel hidden ember-view" id="ember116" src="https://px.ads.linkedin.com/collect/?pid=6883&amp;fmt=gif&amp;_t=1607510838843"/>
# </div>
# <div id="li-modal-container"></div>
# <div id="artdeco-hoverable-outlet"></div>
# <div class="entity-hovercard-container hidden ember-view" id="ember8"><div class="entity-hovercard p4" role="tooltip" tabindex="-1">
# <section class="entity-hovercard__loading-state">
#       Loading…
#     </section>
# </div>
# </div>
# <!-- -->
# <!-- -->
# <div class="type-ahead type-ahead-wormhole" id="type-ahead-wormhole">
# </div>
# <div class="toast-wormhole" id="toast-wormhole">
# </div>
# <!-- -->
# <div><!-- --></div>
# </body></html>

# %%
name_div = soup.find('div',{'class':'flex-1 mr5'})
name_div
# Out:
# <div class="flex-1 mr5">
# <ul class="pv-top-card--list inline-flex align-items-center">
# <li class="inline t-24 t-black t-normal break-words">
#             Rishabh Singh
#           </li>
# <!-- --><!-- --> <li class="inline-flex ml2">
# <span class="pv-member-badge--for-top-card inline-flex pv-member-badge ember-view" id="ember66" style="display: none;"><!-- -->
# <!-- -->
# <span class="visually-hidden">
#   Rishabh has a  account
# </span>
# <!-- --></span>
# </li>
# <!-- --> </ul>
# <h2 class="mt1 t-18 t-black t-normal break-words">
#             #futureshaper
#           </h2>
# <ul class="pv-top-card--list pv-top-card--list-bullet mt1">
# <li class="t-16 t-black t-normal inline-block">
#               Bangalore Urban, Karnataka, India
#             </li>
# <!-- -->
# <li class="inline-block">
# <span class="t-16 t-black t-normal">
#                   500+ connections
#                 </span>
# </li>
# <li class="inline-block">
# <a class="ember-view" data-control-name="contact_see_more" href="/in/rishabh-singh-61b706114/detail/contact-info/" id="ember67"> <span class="t-16 link-without-visited-state">
#                   Contact info
#                 </span>
# </a> </li>
# </ul>
# </div>

# %%
name_loc = name_div.find_all('ul')
name = name_loc[0].find('li').get_text().strip()
name
# Out:
# 'Rishabh Singh'

# %%
loc = name_loc[1].find('li').get_text().strip()
loc
# Out:
# 'Bangalore Urban, Karnataka, India'

# %%
profile_title = name_div.find('h2').get_text().strip()
profile_title
# Out:
# '#futureshaper'

# %%
connection = name_loc[1].find_all('li')
connection = connection[1].get_text().strip()
connection
# Out:
# '500+ connections'

# %%
info = []
info.append(link)
info.append(name)
info.append(profile_title)
info.append(loc)
info.append(connection)
info
# Out:
# ['https://www.linkedin.com/in/rishabh-singh-61b706114/',
#  'Rishabh Singh',
#  '#futureshaper',
#  'Bangalore Urban, Karnataka, India',
#  '500+ connections']

# %%
about_div = soup.find('div',{'class':'pv-oc ember-view'})
about = about_div.find('p').get_text().strip().replace("\n","")
about
# Out:
# 'Experienced Field-Programmable Gate Arrays Engineer with a demonstrated history of working in the electronicmanufacturing industry. Skilled in VHDL, Design Engineering, Verilog, Timing Closure, Field-Programmable Gate      Arrays (FPGA), and SQL. Currently associated with Honeywell International Inc. Strong engineering professi...see more... see more'

# %% [markdown]
# ### Experience

# %%
# exp_section = soup.find('section',{'id':'experience-section'})
# experience = exp_section.find('ul').get_text().strip().replace("\n","")
# experience

# %%
exp_section = soup.find('section',{'id':'experience-section'})
exp_section = exp_section.find('ul')
li_tags = exp_section.find('div')
a_tags = li_tags.find('a')
a_tags
# Out:
# <a class="full-width ember-view" data-control-name="background_details_company" href="/company/honeywell/" id="ember129"> <div class="pv-entity__logo company-logo">
# <img alt="Honeywell" class="pv-entity__logo-img EntityPhoto-square-5 lazy-image ember-view" id="ember131" loading=""/>
# </div>
# <div class="pv-entity__summary-info pv-entity__summary-info--background-section">
# <h3 class="t-16 t-black t-bold">FPGA Engineer</h3>
# <p class="visually-hidden">Company Name</p>
# <p class="pv-entity__secondary-title t-14 t-black t-normal">
#       Honeywell
# <!-- --> </p>
# <div class="display-flex">
# <h4 class="pv-entity__date-range t-14 t-black--light t-normal">
# <span class="visually-hidden">Dates Employed</span>
# <span>Aug 2019 – Present</span>
# </h4>
# <h4 class="t-14 t-black--light t-normal">
# <span class="visually-hidden">Employment Duration</span>
# <span class="pv-entity__bullet-item-v2">1 yr 5 mos</span>
# </h4>
# </div>
# <h4 class="pv-entity__location t-14 t-black--light t-normal block">
# <span class="visually-hidden">Location</span>
# <span>Bengaluru Area, India</span>
# </h4>
# <!-- -->
# </div>
# </a>

# %%
job_title = a_tags.find('h3').get_text().strip()
job_title
# Out:
# 'FPGA Engineer'

# %%
company_name = a_tags.find_all('p')[1].get_text().strip()
company_name
# Out:
# 'Honeywell'

# %%
joining_date = a_tags.find_all('h4')[0].find_all('span')[1].get_text().strip()
joining_date
# Out:
# 'Aug 2019 – Present'

# %%
exp = a_tags.find_all('h4')[1].find_all('span')[1].get_text().strip()
exp
# Out:
# '1 yr 5 mos'

# %%
info.append(company_name)
info.append(job_title)
info.append(joining_date)
info.append(exp)

# %%
info
# Out:
# ['https://www.linkedin.com/in/rishabh-singh-61b706114/',
#  'Rishabh Singh',
#  '#futureshaper',
#  'Bangalore Urban, Karnataka, India',
#  '500+ connections',
#  'Honeywell',
#  'FPGA Engineer',
#  'Aug 2019 – Present',
#  '1 yr 5 mos']

# %% [markdown]
# ###Education

# %%
edu_section = soup.find('section',{'id':'education-section'}).find('ul')
edu_section
# Out:
# <ul class="pv-profile-section__section-info section-info pv-profile-section__section-info--has-no-more">
# <li class="pv-profile-section__list-item pv-education-entity pv-profile-section__card-item ember-view" id="356637700"><div class="display-flex justify-space-between full-width">
# <div class="display-flex flex-column full-width">
# <a class="ember-view" data-control-name="background_details_school" href="/school/223389/?legacySchoolId=223389" id="ember144"> <div class="pv-entity__logo">
# <img alt="Technocrats Institute of Technology (Excellence), Anand Nagar, PB No. 24, Post Piplani, BHEL, Bhopal - 462021" class="pv-entity__logo-img pv-entity__logo-img EntityPhoto-square-4 lazy-image ghost-school ember-view" id="ember146" loading=""/>
# </div>
# <div class="pv-entity__summary-info pv-entity__summary-info--background-section">
# <div class="pv-entity__degree-info">
# <h3 class="pv-entity__school-name t-16 t-black t-bold">Technocrats Institute of Technology (Excellence), Anand Nagar, PB No. 24, Post Piplani, BHEL, Bhopal - 462021</h3>
# <p class="pv-entity__secondary-title pv-entity__degree-name t-14 t-black t-normal">
# <span class="visually-hidden">Degree Name</span>
# <span class="pv-entity__comma-item">Bachelor of Engineering (B.E.)</span>
# </p>
# <p class="pv-entity__secondary-title pv-entity__fos t-14 t-black t-normal">
# <span class="visually-hidden">Field Of Study</span>
# <span class="pv-entity__comma-item">Electrical, Electronics and Communications Engineering</span>
# </p>
# <p class="pv-entity__secondary-title pv-entity__grade t-14 t-black t-normal">
# <span class="visually-hidden">Grade</span>
# <span class="pv-entity__comma-item">FIRST</span>
# </p>
# </div>
# <p class="pv-entity__dates t-14 t-black--light t-normal">
# <span class="visually-hidden">Dates attended or expected graduation</span>
# <span>
# <time>2012</time> – <time>2016</time>
# </span>
# </p>
# <!-- --></div>
# </a>
# <!-- --> </div>
# <!-- --></div>
# </li>
# <li class="pv-profile-section__list-item pv-education-entity pv-profile-section__card-item ember-view" id="373985416"><div class="display-flex justify-space-between full-width">
# <div class="display-flex flex-column full-width">
# <a class="ember-view" data-control-name="background_details_school" href="/search/results/all/?keywords=S.H.S.B.B" id="ember149"> <div class="pv-entity__logo">
# <img alt="S.H.S.B.B" class="pv-entity__logo-img pv-entity__logo-img EntityPhoto-square-4 lazy-image ghost-school ember-view" id="ember151" loading=""/>
# </div>
# <div class="pv-entity__summary-info pv-entity__summary-info--background-section">
# <div class="pv-entity__degree-info">
# <h3 class="pv-entity__school-name t-16 t-black t-bold">S.H.S.B.B</h3>
# <!-- --> <p class="pv-entity__secondary-title pv-entity__fos t-14 t-black t-normal">
# <span class="visually-hidden">Field Of Study</span>
# <span class="pv-entity__comma-item">PCM</span>
# </p>
# <!-- --> </div>
# <!-- -->
# <!-- --></div>
# </a>
# <!-- --> </div>
# <!-- --></div>
# </li>
# </ul>

# %%
college_name = edu_section.find('h3').get_text().strip()
college_name
# Out:
# 'Technocrats Institute of Technology (Excellence), Anand Nagar, PB No. 24, Post Piplani, BHEL, Bhopal - 462021'

# %%
degree = edu_section.find('p',{'class':'pv-entity__secondary-title pv-entity__degree-name t-14 t-black t-normal'}).find_all('span')[1].get_text().strip()

# %%
degree
# Out:
# 'Bachelor of Engineering (B.E.)'

# %%
stream = edu_section.find('p',{'class':'pv-entity__secondary-title pv-entity__fos t-14 t-black t-normal'}).find_all('span')[1].get_text().strip()
stream
# Out:
# 'Electrical, Electronics and Communications Engineering'

# %%
degree_yr = edu_section.find('p',{'class':'pv-entity__dates t-14 t-black--light t-normal'}).find_all('span')[1].get_text().strip()
degree_yr
# Out:
# '2012 – 2016'

# %%
info.append(college_name)
info.append(degree)
info.append(stream)
info.append(degree_yr)

# %%
info
# Out:
# ['https://www.linkedin.com/in/rishabh-singh-61b706114/',
#  'Rishabh Singh',
#  '#futureshaper',
#  'Bangalore Urban, Karnataka, India',
#  '500+ connections',
#  'Honeywell',
#  'FPGA Engineer',
#  'Aug 2019 – Present',
#  '1 yr 5 mos',
#  'Technocrats Institute of Technology (Excellence), Anand Nagar, PB No. 24, Post Piplani, BHEL, Bhopal - 462021',
#  'Bachelor of Engineering (B.E.)',
#  'Electrical, Electronics and Communications Engineering',
#  '2012 – 2016']
